# %%
import pandas as pd
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt

# !pip install -q -U tensorflow==1.8.0
import tensorflow as tf

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %%
data = pd.read_csv(url, names = names)

# %%
data.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
feature_names = ['preg','plas','pres','skin','test','mass', 'pedi', 'age']
X = data.loc[:, feature_names]
y = data['class']

# %%
X[0:5]
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age
# 0     6   148    72    35     0  33.6  0.627   50
# 1     1    85    66    29     0  26.6  0.351   31
# 2     8   183    64     0     0  23.3  0.672   32
# 3     1    89    66    23    94  28.1  0.167   21
# 4     0   137    40    35   168  43.1  2.288   33

# %%
y[0:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: class, dtype: int64

# %%
len(X)
# Out:
# 768

# %%
TRAINING_SIZE = 688
TEST_SIZE = 80

# %%
(train_X, train_y), (test_X, test_y) = (X[:TRAINING_SIZE], y[:TRAINING_SIZE]), (X[TRAINING_SIZE:], y[TRAINING_SIZE:])

# %%
# Normalize data by removing the mean and scaling to unit variance from each feature

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

train_X = scaler.fit_transform(train_X)

test_X = scaler.fit_transform(test_X)

# %%
np.random.seed(0)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(55, activation=tf.nn.relu, input_shape=(8,)))
model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid))


# Create a TensorFlow optimizer, rather than using the Keras version
# This is currently necessary when working in eager mode
optimizer = tf.train.AdamOptimizer(learning_rate=0.005)

# We will now compile and print out a summary of our model
model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 55)                495
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 56
# ...
# Total params: 551
# Trainable params: 551
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_X, train_y, batch_size = 3, epochs=10)
# Out:
# Epoch 1/10
# 688/688 [==============================] - 1s 793us/step - loss: 0.5053 - acc: 0.7529
# Epoch 2/10
# 688/688 [==============================] - 0s 413us/step - loss: 0.4702 - acc: 0.7703
# Epoch 3/10
# 688/688 [==============================] - 0s 411us/step - loss: 0.4578 - acc: 0.7587
# Epoch 4/10
# 688/688 [==============================] - 0s 409us/step - loss: 0.4489 - acc: 0.7892
# Epoch 5/10
# 688/688 [==============================] - 0s 431us/step - loss: 0.4567 - acc: 0.7791
# Epoch 6/10
# 688/688 [==============================] - 0s 567us/step - loss: 0.4443 - acc: 0.7863
# Epoch 7/10
# 688/688 [==============================] - 0s 484us/step - loss: 0.4464 - acc: 0.7907
# Epoch 8/10
# 688/688 [==============================] - 0s 503us/step - loss: 0.4400 - acc: 0.7878
# Epoch 9/10
# 688/688 [==============================] - 0s 483us/step - loss: 0.4348 - acc: 0.7834
# Epoch 10/10
# ...

# %%
EPOCHS=5

for epoch in range(EPOCHS):
  for X, y in dataset:
    train_loss, train_accuracy = model.train_on_batch(X, y)
  
  # Here you can gather any metrics or adjust your training parameters
  print('Epoch #%d\t Loss: %.6f\tAccuracy: %.6f' % (epoch + 1, train_loss, train_accuracy))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-879a382b3968> in <module>()
#       2
#       3 for epoch in range(EPOCHS):
# ----> 4   for X, y in dataset:
#       5     train_loss, train_accuracy = model.train_on_batch(X, y)
#       6
#
# NameError: name 'dataset' is not defined

# %%
loss, accuracy = model.evaluate(test_X, test_y)
print('Test accuracy: %.2f' % (accuracy))
# Out:
# 80/80 [==============================] - 0s 1ms/step
# Test accuracy: 0.79
